# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter

# %%
# Colors
colors = ['red','green','pink','orange','purple','blue','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple','red','blue','green','pink','orange','purple']

# %%
df1 = pd.read_csv('Day1.csv')
df2 = pd.read_csv('Day2.csv')
df3 = pd.read_csv('Day3.csv')
df4 = pd.read_csv('Day4.csv')
df5 = pd.read_csv('Day5.csv')
df6 = pd.read_csv('Day6.csv')
df7 = pd.read_csv('Day7.csv')
df8 = pd.read_csv('Day8.csv')
df9 = pd.read_csv('Day9.csv')
df10 = pd.read_csv('Day10.csv')

# %%
csv_data = ['Day1.csv','Day2.csv','Day3.csv','Day4.csv','Day5.csv','Day6.csv','Day7.csv','Day8.csv','Day9.csv','Day10.csv']

# %%
color_d = {'red zero line': '#FF0000', 'blue one line': '#0000FF'}
cols = ['red zero line', 'blue one line', 'green two line']

for csv in csv_data:
    df= pd.read_csv(csv)
    
    print(df)

    df.plot(x='Time',y='Event')
    break
    plt.title(csv,fontweight="bold")
    plt.xlabel("Minutes")
    plt.ylabel("Event")
    plt.legend()
# Out:
#           Time  Event
# 0          0.0      0
# 1          1.5      0
# 2          3.0      0
# 3          4.5      0
# 4          6.0      0
# ...        ...    ...
# 9996   14994.0      0
# 9997   14995.5      0
# 9998   14997.0      0
# 9999   14998.5      0
# 10000  15000.0      0
#
# [10001 rows x 2 columns]

# %%
fig, ax = plt.subplots(3, 4, figsize=(10,7))
fig.tight_layout(pad=5)


for i in range(3):
    for j in range(4):
        if ((i*4)+(j)) < 10:
            df = pd.read_csv(csvs[(i*4)+(j)])
            ax[i, j].plot(df['Time'], df['Event'])
            ax[i, j].set_title("Day"+str((i*4)+j+1),fontweight = "bold")
            fig.suptitle("t-Minute Clustering")
            #.xlabel("Minutes")
#             plt.ylabel("Event")
for ax in ax.flat:
    ax.set(xlabel='Minutes', ylabel='Event')     
fig.legend(['Event'])

# %%
plt.plot(df1['Time'], df1['Event'])

# %% [markdown]
# ## Part 2

# %%
import matplotlib.cm as cm
from numpy import linspace

# %%
data = {'Number of cluster - 3 min':  '',
        'Number of cluster - 5 min':  '',
        'Number of cluster - 10 min':  ''
        }

csvDF = pd.DataFrame(data,index=[])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(12,10)})
df = pd.read_csv('Day1.csv')

dfIntervals = df.copy()
dfIntervals = dfIntervals.drop(df.index)
intervalCounter = 1
for i,r in df.iterrows():
    dfIntervals = dfIntervals.append(r)
    if(r.Time>(180*intervalCounter)):
        intervalCounter = intervalCounter+1
        #print(dfIntervals)
        sns.lineplot(x='Time',y='Event',data=dfIntervals,color=colors[intervalCounter-1], linewidth=1)
        dfIntervals = dfIntervals.drop(dfIntervals.index)

plt.show()

# %%
fig, ax = plt.subplots(3, 4, figsize=(10,7))
fig.tight_layout(pad=5)

clusterCounter = 0
for i in range(3):
    for j in range(4):
        if ((i*4)+(j)) < 10:
            clusterCounter = 0
            df = pd.read_csv(csvs[(i*4)+(j)])
            dfIntervals = df.copy()
            dfIntervals = dfIntervals.drop(df.index)
            intervalCounter = 1
            hasPositiveSpike = False
            for a,r in df.iterrows():
                dfIntervals = dfIntervals.append(r)
                if(r.Event>0):
                    hasPositiveSpike=True
                if(r.Time>(600*intervalCounter)):
                    intervalCounter = intervalCounter+1
                  
                    if(hasPositiveSpike):
                        clusterCounter = clusterCounter+1
                    hasPositiveSpike = False
                    
                    
                    sns.lineplot(x='Time',y='Event',data=dfIntervals,ax=ax[i, j],color=colors[intervalCounter-1], linewidth=1)
                    dfIntervals = dfIntervals.drop(dfIntervals.index)
                fig.suptitle("t-Minute Clustering")
            
            
            csvData = {#'Number of cluster - 3 min':  '-',
                    #'Number of cluster - 5 min':  '-',
                    'Number of cluster - 10 min':  clusterCounter
                    }
            csvDF = csvDF.append(csvData,ignore_index=True)
            print(' '+str(((i*4)+(j))+1)+':'+str(clusterCounter))
            print('cluster for day '+str(((i*4)+(j))+1)+':'+str(clusterCounter))
           
            
for ax in ax.flat:
    ax.set(xlabel='Minutes', ylabel='Event')     
fig.legend(['Event'])
plt.show()
# Out:
# current cluster counter for day 1:16
# current cluster counter for day 2:22
# current cluster counter for day 3:10
# current cluster counter for day 4:22
# current cluster counter for day 5:11
# current cluster counter for day 6:17
# current cluster counter for day 7:13
# current cluster counter for day 8:19
# current cluster counter for day 9:20
# current cluster counter for day 10:17

# %%
fig, ax = plt.subplots(3, 4, figsize=(10,7))
fig.tight_layout(pad=5)

clusterCounter5 = 0
for i in range(3):
    for j in range(4):
        if ((i*4)+(j)) < 10:
            clusterCounter5 = 0
            df = pd.read_csv(csvs[(i*4)+(j)])
            dfIntervals = df.copy()
            dfIntervals = dfIntervals.drop(df.index)
            intervalCounter = 1
            hasPositiveSpike = False
            for a,r in df.iterrows():
                dfIntervals = dfIntervals.append(r)
                if(r.Event>0):
                    hasPositiveSpike=True
                if(r.Time>(300*intervalCounter)):
                    intervalCounter = intervalCounter+1
                    
                    if(hasPositiveSpike):
                        clusterCounter5 = clusterCounter5+1
                    hasPositiveSpike = False
              
                    
            
                    
   
                    sns.lineplot(x='Time',y='Event',data=dfIntervals,ax=ax[i, j],color=colors[intervalCounter-1], linewidth=1)
                    dfIntervals = dfIntervals.drop(dfIntervals.index)
                
                    fig.suptitle("t-Minute Clustering")
            
                csvData = {#'Number of cluster - 3 min': clusterCounter3,
                            'Number of cluster - 5 min':  clusterCounter5,
                            #'Number of cluster - 10 min':  clusterCounter
                          } 
                csvDF = csvDF.append(csvData,ignore_index=True)
            print('cluster now '+str(((i*4)+(j))+1)+':'+str(clusterCounter5))
           
            
            
for ax in ax.flat:
    ax.set(xlabel='Minutes', ylabel='Event')     
fig.legend(['Event'])
plt.show()
# Out:
# cluster for today 1:23
# cluster for today 2:30
# cluster for today 3:12
# cluster for today 4:29
# cluster for today 5:16
# cluster for today 6:27
# cluster for today 7:17
# cluster for today 8:26

# %%
fig, ax = plt.subplots(3, 4, figsize=(10,7))
fig.tight_layout(pad=5)

clusterCounter3 = 0
for i in range(3):
    for j in range(4):
        if ((i*4)+(j)) < 10:
            clusterCounter3 = 0
            df = pd.read_csv(csvs[(i*4)+(j)])
            
            dfIntervals = df.copy()
            dfIntervals = dfIntervals.drop(df.index)
            intervalCounter = 1
            hasPositiveSpike = False
            for a,r in df.iterrows():
                dfIntervals = dfIntervals.append(r)
                if(r.Event>0):
                    hasPositiveSpike=True
                if(r.Time>(180*intervalCounter)):
                    intervalCounter = intervalCounter+1
                    
                    if(hasPositiveSpike):
                        clusterCounter3 = clusterCounter3+1
                    hasPositiveSpike = False
                    #print(i, j)
                    
                    sns.lineplot(x='Time',y='Event',data=dfIntervals,ax=ax[i, j],color=colors[intervalCounter-1], linewidth=1)
                    dfIntervals = dfIntervals.drop(dfIntervals.index)
                fig.suptitle("t-Minute Clustering")
            
            
            csvData = {'Number of cluster - 3 min':  clusterCounter3,
                        #'Number of cluster - 5 min':  clusterCounter5,
                        #'Number of cluster - 10 min':  clusterCounter
                    }
            csvDF = csvDF.append(csvData,ignore_index=True)
            print('Cluster now '+str(((i*4)+(j))+1)+':'+str(clusterCounter3))
           
            
            
for ax in ax.flat:
    ax.set(xlabel='Minutes', ylabel='Event')     
fig.legend(['Event'])
plt.show()
# Out:
# Loading!!!!t is 3 mins(180 seconds)...

# %% [markdown]
# ## Part 3

# %%
csvDF.to_csv('Akshaya_Mahesh_HW06_part3.csv')
